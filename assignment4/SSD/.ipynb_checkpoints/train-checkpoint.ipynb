# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 
import logging
import os
import pathlib
import torch
from ssd.engine.inference import do_evaluation
from ssd.config.defaults import cfg
from ssd.utils.logger import setup_logger
from train import start_train

# %%
#config_file = "configs/vgg_ssd300_voc0712_tdt4265_server.yaml"
config_file = "configs/mnist_tdt4265_server.yaml"

cfg.merge_from_file(config_file)
cfg.freeze()
output_dir = pathlib.Path(cfg.OUTPUT_DIR)
output_dir.mkdir(exist_ok=True, parents=True)

logger = setup_logger("SSD", output_dir)

logger.info("Loaded configuration file {}".format(config_file))
with open(config_file, "r") as cf:
    config_str = "\n" + cf.read()
    logger.info(config_str)
logger.info("Running with config:\n{}".format(cfg))
# Out:
# 2021-03-17 13:00:59,116 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:00:59,116 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:00:59,116 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:00:59,116 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:00:59,116 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:00:59,116 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:00:59,116 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:00:59,116 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:00:59,116 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:00:59,116 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:00:59,128 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 32
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:00:59,128 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 32
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:00:59,128 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 32
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:00:59,128 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 32
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:00:59,128 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 32
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:00:59,128 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 32
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:00:59,128 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 32
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:00:59,128 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 32
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:00:59,128 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 32
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:00:59,128 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [128, 256, 128, 128, 64, 64]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 32
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:00:59,131 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 32
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:00:59,131 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 32
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:00:59,131 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 32
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:00:59,131 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 32
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:00:59,131 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 32
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:00:59,131 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 32
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:00:59,131 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 32
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:00:59,131 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 32
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:00:59,131 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 32
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:00:59,131 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (128, 256, 128, 128, 64, 64)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 32
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45

# %%
model = start_train(cfg)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-c4141bd7d278> in <module>
# ----> 1 model = start_train(cfg)
#
# ~/home/CV_DL_Jupyter/Computer-Vision-and-Deep-Learning/assignment4/SSD/train.py in start_train(cfg)
#      33 def start_train(cfg):
#      34     logger = logging.getLogger('SSD.trainer')
# ---> 35     model = SSDDetector(cfg)
#      36     model = torch_utils.to_cuda(model)
#      37
#
# ~/home/CV_DL_Jupyter/Computer-Vision-and-Deep-Learning/assignment4/SSD/ssd/modeling/detector.py in __init__(self, cfg)
#      12         super().__init__()
#      13         self.cfg = cfg
# ---> 14         self.backbone = build_backbone(cfg)
#      15         self.box_head = SSDBoxHead(cfg)
#      16         print(
#
# ~/home/CV_DL_Jupyter/Computer-Vision-and-Deep-Learning/assignment4/SSD/ssd/modeling/detector.py in build_backbone(cfg)
#      36         return model
#      37     if backbone_name == "improved_basic":
# ---> 38         model = ImprovedBasicModel(cfg)
#      39         return model
#      40     if backbone_name == "vgg":
#
# ~/home/CV_DL_Jupyter/Computer-Vision-and-Deep-Learning/assignment4/SSD/ssd/modeling/backbone/improved_basic.py in __init__(self, cfg)
#      36                     stride=2
#      37                 ),
# ---> 38                 nn.Conv2d(
#      39                     in_channels=64,
#      40                     out_channels=output_channels[0]/4,
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/conv.py in __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, groups, bias, padding_mode)
#     379         padding = _pair(padding)
#     380         dilation = _pair(dilation)
# --> 381         super(Conv2d, self).__init__(
#     382             in_channels, out_channels, kernel_size, stride, padding, dilation,
#     383             False, _pair(0), groups, bias, padding_mode)
#
# /opt/conda/lib/python3.8/site-packages/torch/nn/modules/conv.py in __init__(self, in_channels, out_channels, kernel_size, stride, padding, dilation, transposed, output_padding, groups, bias, padding_mode)
#     101                 in_channels, out_channels // groups, *kernel_size))
#     102         else:
# --> 103             self.weight = Parameter(torch.Tensor(
#     104                 out_channels, in_channels // groups, *kernel_size))
#     105         if bias:
#
# TypeError: new() received an invalid combination of arguments - got (float, int, int, int), but expected one of:
#  * (*, torch.device device)
#  * (torch.Storage storage)
#  * (Tensor other)
#  * (tuple of ints size, *, torch.device device)
#  * (object data, *, torch.device device)

# %%
logger.info('Start evaluating...')
torch.cuda.empty_cache()  # speed up evaluating after training finished
do_evaluation(cfg, model)
# Out:
# 2021-03-17 12:59:46,319 SSD INFO: Start evaluating...
# 2021-03-17 12:59:46,319 SSD INFO: Start evaluating...
# 2021-03-17 12:59:46,319 SSD INFO: Start evaluating...
# 2021-03-17 12:59:46,319 SSD INFO: Start evaluating...
# 2021-03-17 12:59:46,319 SSD INFO: Start evaluating...
# 2021-03-17 12:59:46,319 SSD INFO: Start evaluating...
# 2021-03-17 12:59:46,319 SSD INFO: Start evaluating...
# 2021-03-17 12:59:46,319 SSD INFO: Start evaluating...
# 2021-03-17 12:59:46,472 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 12:59:46,472 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 12:59:46,472 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 12:59:46,472 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 12:59:46,472 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 12:59:46,472 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 12:59:46,472 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 12:59:46,472 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 100%|██████████| 100/100 [00:02<00:00, 35.74it/s]
# 2021-03-17 12:59:49,953 SSD.inference INFO: mAP: 0.8244
# 0               : 0.8674
# 1               : 0.7590
# 2               : 0.8046
# 3               : 0.8459
# 4               : 0.8355
# 5               : 0.8319
# 6               : 0.8366
# 7               : 0.8135
# 8               : 0.8476
# 9               : 0.8025
#
# 2021-03-17 12:59:49,953 SSD.inference INFO: mAP: 0.8244
# 0               : 0.8674
# 1               : 0.7590
# 2               : 0.8046
# 3               : 0.8459
# 4               : 0.8355
# 5               : 0.8319
# 6               : 0.8366
# 7               : 0.8135
# 8               : 0.8476
# 9               : 0.8025
#
# 2021-03-17 12:59:49,953 SSD.inference INFO: mAP: 0.8244
# 0               : 0.8674
# 1               : 0.7590
# 2               : 0.8046
# 3               : 0.8459
# 4               : 0.8355
# 5               : 0.8319
# 6               : 0.8366
# 7               : 0.8135
# 8               : 0.8476
# 9               : 0.8025
#
# 2021-03-17 12:59:49,953 SSD.inference INFO: mAP: 0.8244
# 0               : 0.8674
# 1               : 0.7590
# 2               : 0.8046
# 3               : 0.8459
# 4               : 0.8355
# 5               : 0.8319
# 6               : 0.8366
# 7               : 0.8135
# 8               : 0.8476
# 9               : 0.8025
#
# 2021-03-17 12:59:49,953 SSD.inference INFO: mAP: 0.8244
# 0               : 0.8674
# 1               : 0.7590
# 2               : 0.8046
# 3               : 0.8459
# 4               : 0.8355
# 5               : 0.8319
# 6               : 0.8366
# 7               : 0.8135
# 8               : 0.8476
# 9               : 0.8025
#
# 2021-03-17 12:59:49,953 SSD.inference INFO: mAP: 0.8244
# 0               : 0.8674
# 1               : 0.7590
# 2               : 0.8046
# 3               : 0.8459
# 4               : 0.8355
# 5               : 0.8319
# 6               : 0.8366
# 7               : 0.8135
# 8               : 0.8476
# 9               : 0.8025
#
# 2021-03-17 12:59:49,953 SSD.inference INFO: mAP: 0.8244
# 0               : 0.8674
# 1               : 0.7590
# 2               : 0.8046
# 3               : 0.8459
# 4               : 0.8355
# 5               : 0.8319
# 6               : 0.8366
# 7               : 0.8135
# 8               : 0.8476
# 9               : 0.8025
#
# 2021-03-17 12:59:49,953 SSD.inference INFO: mAP: 0.8244
# 0               : 0.8674
# 1               : 0.7590
# 2               : 0.8046
# 3               : 0.8459
# 4               : 0.8355
# 5               : 0.8319
# 6               : 0.8366
# 7               : 0.8135
# 8               : 0.8476
# 9               : 0.8025
# [{'metrics': {'mAP': 0.824449647349199,
#    '0': 0.8673696552012528,
#    '1': 0.7590147754367458,
#    '2': 0.8046473550023852,
#    '3': 0.8458781688235317,
#    '4': 0.8354820586359086,
#    '5': 0.83191578865153,
#    '6': 0.8365963314493917,
#    '7': 0.8135151041762634,
#    '8': 0.8475586201028042,
#    '9': 0.8025186160121778}}]
