# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 
import logging
import os
import pathlib
import torch
from ssd.engine.inference import do_evaluation
from ssd.config.defaults import cfg
from ssd.utils.logger import setup_logger
from train import start_train

# %%
#config_file = "configs/vgg_ssd300_voc0712_tdt4265_server.yaml"
config_file = "configs/mnist_tdt4265_server-improved.yaml"

cfg.merge_from_file(config_file)
cfg.freeze()
output_dir = pathlib.Path(cfg.OUTPUT_DIR)
output_dir.mkdir(exist_ok=True, parents=True)

logger = setup_logger("SSD", output_dir)

logger.info("Loaded configuration file {}".format(config_file))
with open(config_file, "r") as cf:
    config_str = "\n" + cf.read()
    logger.info(config_str)
logger.info("Running with config:\n{}".format(cfg))
# Out:
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,452 SSD INFO: Loaded configuration file configs/mnist_tdt4265_server-improved.yaml
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,469 SSD INFO:
# MODEL:
#     NUM_CLASSES: 11
#     BACKBONE:
#         NAME: 'improved_basic'
#         PRETRAINED: False
#         OUT_CHANNELS: [256, 512, 256, 256, 128, 128]
#         INPUT_CHANNELS: 3
# INPUT:
#     IMAGE_SIZE: [300, 300]
# DATASETS:
#     TRAIN: ("mnist_detection_train", "mnist_detection_val")
#     TEST: ("mnist_detection_val", )
# SOLVER:
#     MAX_ITER: 10000
#     GAMMA: 0.1
#     BATCH_SIZE: 16
#     LR: 2e-3
# OUTPUT_DIR: 'outputs/improved_basic'
# DATASET_DIR: "/work/datasets"
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45
# 2021-03-17 13:50:24,476 SSD INFO: Running with config:
# DATASETS:
#   TEST: ('mnist_detection_val',)
#   TRAIN: ('mnist_detection_train', 'mnist_detection_val')
# DATASET_DIR: /work/datasets
# DATA_LOADER:
#   NUM_WORKERS: 4
#   PIN_MEMORY: True
# EVAL_STEP: 500
# INPUT:
#   IMAGE_SIZE: [300, 300]
#   PIXEL_MEAN: [123.675, 116.28, 103.53]
#   PIXEL_STD: [1, 1, 1]
# LOG_STEP: 10
# MODEL:
#   BACKBONE:
#     INPUT_CHANNELS: 3
#     NAME: improved_basic
#     OUT_CHANNELS: (256, 512, 256, 256, 128, 128)
#     PRETRAINED: False
#   CENTER_VARIANCE: 0.1
#   NEG_POS_RATIO: 3
#   NUM_CLASSES: 11
#   PRIORS:
#     ASPECT_RATIOS: [[2], [2, 3], [2, 3], [2, 3], [2], [2]]
#     BOXES_PER_LOCATION: [4, 6, 6, 6, 4, 4]
#     CLIP: True
#     FEATURE_MAPS: [[38, 38], [19, 19], [10, 10], [5, 5], [3, 3], [1, 1]]
#     MAX_SIZES: [[60, 60], [111, 111], [162, 162], [213, 213], [264, 264], [315, 315]]
#     MIN_SIZES: [[30, 30], [60, 60], [111, 111], [162, 162], [213, 213], [264, 264]]
#     STRIDES: [[8, 8], [16, 16], [32, 32], [64, 64], [100, 100], [300, 300]]
#   SIZE_VARIANCE: 0.2
#   THRESHOLD: 0.5
# MODEL_SAVE_STEP: 500
# OUTPUT_DIR: outputs/improved_basic
# SOLVER:
#   BATCH_SIZE: 16
#   GAMMA: 0.1
#   LR: 0.002
#   MAX_ITER: 10000
#   MOMENTUM: 0.9
#   WEIGHT_DECAY: 0.0005
# TEST:
#   BATCH_SIZE: 10
#   CONFIDENCE_THRESHOLD: 0.01
#   MAX_PER_CLASS: -1
#   MAX_PER_IMAGE: 100
#   NMS_THRESHOLD: 0.45

# %%
model = start_train(cfg)
# Out:
# Detector initialized. Total Number of params:  9.17M
# Backbone number of parameters: 8.06M
# SSD Head number of parameters: 1.11M
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:25,576 SSD.trainer INFO: No checkpoint found.
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:26,900 SSD.trainer INFO: Start training ...
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:28,450 SSD.trainer INFO: iter: 000010, lr: 0.00012, total_loss: 12.703 (12.703), reg_loss: 2.907 (2.907), cls_loss: 9.796 (9.796), time: 0.153 (0.153), eta: 0:25:31, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:29,542 SSD.trainer INFO: iter: 000020, lr: 0.00022, total_loss: 12.560 (12.632), reg_loss: 2.867 (2.887), cls_loss: 9.693 (9.745), time: 0.109 (0.131), eta: 0:21:49, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:30,644 SSD.trainer INFO: iter: 000030, lr: 0.00032, total_loss: 12.474 (12.579), reg_loss: 2.846 (2.873), cls_loss: 9.628 (9.706), time: 0.110 (0.124), eta: 0:20:38, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:31,734 SSD.trainer INFO: iter: 000040, lr: 0.00042, total_loss: 12.423 (12.540), reg_loss: 2.840 (2.865), cls_loss: 9.584 (9.675), time: 0.109 (0.120), eta: 0:19:59, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:32,845 SSD.trainer INFO: iter: 000050, lr: 0.00052, total_loss: 12.340 (12.500), reg_loss: 2.804 (2.853), cls_loss: 9.537 (9.648), time: 0.111 (0.119), eta: 0:19:39, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:33,939 SSD.trainer INFO: iter: 000060, lr: 0.00062, total_loss: 12.237 (12.456), reg_loss: 2.752 (2.836), cls_loss: 9.485 (9.621), time: 0.109 (0.117), eta: 0:19:23, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:35,038 SSD.trainer INFO: iter: 000070, lr: 0.00072, total_loss: 12.129 (12.410), reg_loss: 2.693 (2.815), cls_loss: 9.436 (9.594), time: 0.110 (0.116), eta: 0:19:12, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:36,152 SSD.trainer INFO: iter: 000080, lr: 0.00082, total_loss: 12.025 (12.362), reg_loss: 2.659 (2.796), cls_loss: 9.367 (9.566), time: 0.111 (0.115), eta: 0:19:05, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:37,258 SSD.trainer INFO: iter: 000090, lr: 0.00092, total_loss: 11.836 (12.303), reg_loss: 2.576 (2.771), cls_loss: 9.261 (9.532), time: 0.111 (0.115), eta: 0:18:58, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:38,357 SSD.trainer INFO: iter: 000100, lr: 0.00102, total_loss: 11.544 (12.227), reg_loss: 2.455 (2.740), cls_loss: 9.089 (9.487), time: 0.110 (0.114), eta: 0:18:52, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:39,464 SSD.trainer INFO: iter: 000110, lr: 0.00112, total_loss: 11.084 (12.123), reg_loss: 2.429 (2.712), cls_loss: 8.655 (9.412), time: 0.111 (0.114), eta: 0:18:48, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# 2021-03-17 13:50:40,570 SSD.trainer INFO: iter: 000120, lr: 0.00122, total_loss: 10.017 (11.948), reg_loss: 2.415 (2.687), cls_loss: 7.601 (9.261), time: 0.111 (0.114), eta: 0:18:44, mem: 3471M
# ...
# 2021-03-17 13:53:17,720 SSD.trainer INFO: iter: 001430, lr: 0.01431, total_loss: 2.856 (4.978), reg_loss: 0.754 (1.239), cls_loss: 2.102 (3.739), time: 0.111 (0.119), eta: 0:17:03, mem: 3471M
# 2021-03-17 13:53:17,720 SSD.trainer INFO: iter: 001430, lr: 0.01431, total_loss: 2.856 (4.978), reg_loss: 0.754 (1.239), cls_loss: 2.102 (3.739), time: 0.111 (0.119), eta: 0:17:03, mem: 3471M
# 2021-03-17 13:53:17,720 SSD.trainer INFO: iter: 001430, lr: 0.01431, total_loss: 2.856 (4.978), reg_loss: 0.754 (1.239), cls_loss: 2.102 (3.739), time: 0.111 (0.119), eta: 0:17:03, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:18,827 SSD.trainer INFO: iter: 001440, lr: 0.01441, total_loss: 2.907 (4.964), reg_loss: 0.754 (1.236), cls_loss: 2.153 (3.728), time: 0.111 (0.119), eta: 0:17:01, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:19,943 SSD.trainer INFO: iter: 001450, lr: 0.01451, total_loss: 2.894 (4.950), reg_loss: 0.754 (1.233), cls_loss: 2.140 (3.717), time: 0.112 (0.119), eta: 0:17:00, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:21,049 SSD.trainer INFO: iter: 001460, lr: 0.01461, total_loss: 2.947 (4.936), reg_loss: 0.771 (1.229), cls_loss: 2.176 (3.707), time: 0.111 (0.119), eta: 0:16:58, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M
# 2021-03-17 13:53:22,160 SSD.trainer INFO: iter: 001470, lr: 0.01471, total_loss: 2.921 (4.922), reg_loss: 0.757 (1.226), cls_loss: 2.165 (3.696), time: 0.111 (0.119), eta: 0:16:56, mem: 3471M

# %%
logger.info('Start evaluating...')
torch.cuda.empty_cache()  # speed up evaluating after training finished
do_evaluation(cfg, model)
# Out:
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,471 SSD INFO: Start evaluating...
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 2021-03-17 13:38:32,629 SSD.inference INFO: Evaluating mnist_detection_val dataset(1000 images):
# 100%|██████████| 100/100 [00:02<00:00, 36.21it/s]
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
#
# 2021-03-17 13:38:36,055 SSD.inference INFO: mAP: 0.8071
# 0               : 0.8436
# 1               : 0.7025
# 2               : 0.7850
# 3               : 0.8162
# 4               : 0.8486
# 5               : 0.7931
# 6               : 0.8396
# 7               : 0.7866
# 8               : 0.8471
# 9               : 0.8084
# [{'metrics': {'mAP': 0.8070866151721405,
#    '0': 0.8436460646947568,
#    '1': 0.7025055582126443,
#    '2': 0.7850394027370149,
#    '3': 0.8162182809566443,
#    '4': 0.8485930854354299,
#    '5': 0.7930970290651894,
#    '6': 0.8395803433804941,
#    '7': 0.7865878787572049,
#    '8': 0.847149047920832,
#    '9': 0.808449460561195}}]
